# %%
import pandas as pd
import numpy as np
from sklearn import tree
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import seaborn as sns
from math import log
import matplotlib.pyplot as plt
# %matplotlib inline
import graphviz # conda install gra... or pip install graphviz
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.grid_search import GridSearchCV
from time import time
from operator import itemgetter
from sklearn.cross_validation import  cross_val_score
# Out:
# /Users/jitxu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/jitxu/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
#read data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
#function do preprocessing
def miss_values(df):
    for column in df:
        # Test whether column has null value
        if len(df[column].apply(pd.isnull).value_counts()) > 1:
            #print(column+" has missing value")
            #if column is numeric, fill null with mean
            if df[column].dtype in ('int64','float64'):
                df[column] = df[column].fillna(df[column].mean())
            else:
                df[column] = df[column].fillna("unknown")
def factor_encoding(df):
    for column in df:
        if df[column].dtype == 'object':
            df = df.merge(pd.get_dummies(data=df[column],prefix=column),right_index=True,left_index=True)
            del df[column]
    return df

def plot_tree(clf, columns):
    dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=columns,
                         filled=True, rounded=True,  
                         special_characters=True)  
    graph = graphviz.Source(dot_data)  
    return graph 
# Prints R2 and RMSE scores
def get_score(prediction, lables):    
    print('R2: {}'.format(r2_score(prediction, lables))) #R^2 (coefficient of determination) regression score function.
    print('RMSE: {}'.format(np.sqrt(mean_squared_error(prediction, lables))))

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
train['source'] = 1.0
test['source'] = 0.0

# %%
alls = pd.concat([train,test],ignore_index=True)
miss_values(alls)
alls = factor_encoding(alls)

# %%
train = alls[alls['source'] == 1.0]
train.drop(['source'],inplace=True,axis=1)
test = alls[alls['source'] == 0.0]
test.drop(['source'],inplace=True,axis=1)
# Out:
# /Users/jitxu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/jitxu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
x = train.drop(['SalePrice'],axis=1)
Y = train['SalePrice']
x_test = test.drop(['SalePrice'],axis=1)
x_train, x_vali, Y_train, Y_vali = train_test_split(x, Y, test_size=0.25, random_state=42)

# %% [markdown]
# # DTree

# %%
clf = tree.DecisionTreeRegressor(max_depth = 100,min_samples_leaf=50)
clf.fit(x_train, Y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=100, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=50,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_pred = clf.predict(x_vali)

# %%
plt.figure(figsize=(10, 5))
plt.scatter(Y_vali, y_pred, s=20)
plt.title('Predicted vs. Actual')
plt.xlabel('Actual Sale Price')
plt.ylabel('Predicted Sale Price')

plt.plot([min(Y_vali), max(Y_vali)], [min(Y_vali), max(Y_vali)])
plt.tight_layout()

# %%
x_train.head(10)['OverallQual']
# Out:
# 1023    7
# 810     6
# 1384    6
# 626     5
# 813     6
# 839     5
# 370     6
# 54      5
# 534     8
# 785     6
# Name: OverallQual, dtype: int64

# %%
g = plot_tree(clf, list(x_train.columns))
g

# %%
get_score(Y_vali, y_pred)
# Out:
# R2: 0.690416761471071
# RMSE: 46569.58517443793

# %%
y_train_pred = clf.predict(x_train)
get_score(Y_train, y_train_pred)
# Out:
# R2: 0.6927463700311494
# RMSE: 43191.12820414314

# %% [markdown]
# # Pruning Tree 1

# %%
clf
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
clf = tree.DecisionTreeRegressor(criterion='mse', max_depth=8, max_features=None,
           max_leaf_nodes=None, min_impurity_decrease=0.0,
           min_impurity_split=None, min_samples_leaf=20,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           presort=False, random_state=None, splitter='best')
clf.fit(x_train, Y_train)

g = plot_tree(clf, list(x_train.columns))
g

# %%
print("trainingg error: ")
y_train_pred = clf.predict(x_train)
get_score(Y_train, y_train_pred)
print("test error: ")
y_test_pred = clf.predict(x_vali)
get_score(Y_vali, y_test_pred)
# Out:
# trainingg error:
# R2: 0.8278216394038858
# RMSE: 32332.20482805577
# test error:
# R2: 0.8018099957716616
# RMSE: 37261.00147210146

# %% [markdown]
# # Pruning Tree 2

# %%
clf = tree.DecisionTreeRegressor(criterion='mse', max_depth=1, max_features=None,
           max_leaf_nodes=None, min_impurity_decrease=0.0,
           min_impurity_split=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           presort=False, random_state=None, splitter='best')
clf.fit(x_train, Y_train)

g = plot_tree(clf, list(x_train.columns))
g

# %%
print("training metrics: ")
y_train_pred = clf.predict(x_train)
get_score(Y_train, y_train_pred)
print("test metrics: ")
y_test_pred = clf.predict(x_vali)
get_score(Y_vali, y_test_pred)
# Out:
# training metrics:
# R2: 0.45434052451796925
# RMSE: 57558.15811337717
# test metrics:
# R2: 0.4526750609284531
# RMSE: 61920.75863754396

# %% [markdown]
# # YOur version for parameter tuning

# %%
for depth in range(2,10):
    for leaf_no in range(1,50,10):
        for min_splits in range(2,100,20):
            print('\n when depth = {0}, and leaf_no = {1} , min_splits = {2}'.format(depth, leaf_no, min_splits))
            clf = tree.DecisionTreeRegressor(criterion='mse', max_depth=depth, max_features=None,
            max_leaf_nodes=None, min_impurity_decrease=0.0,
            min_impurity_split=None, min_samples_leaf=leaf_no,
            min_samples_split=min_splits, min_weight_fraction_leaf=0.0,
            presort=False, random_state=None, splitter='best')
            clf.fit(x_train, Y_train)
            print("training metrics: ")
            y_train_pred = clf.predict(x_train)
            get_score(Y_train, y_train_pred)
            print("test metrics: ")
            y_test_pred = clf.predict(x_vali)
            get_score(Y_vali, y_test_pred)
# Out:
#  when depth = 2, and leaf_no = 1 , min_splits = 2
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 1 , min_splits = 22
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 1 , min_splits = 42
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 1 , min_splits = 62
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 1 , min_splits = 82
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 11 , min_splits = 2
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 11 , min_splits = 22
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 11 , min_splits = 42
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 11 , min_splits = 62
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 11 , min_splits = 82
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 21 , min_splits = 2
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 21 , min_splits = 22
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 21 , min_splits = 42
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 21 , min_splits = 62
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 21 , min_splits = 82
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 31 , min_splits = 2
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 31 , min_splits = 22
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 31 , min_splits = 42
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 31 , min_splits = 62
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 31 , min_splits = 82
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 41 , min_splits = 2
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 41 , min_splits = 22
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 41 , min_splits = 42
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 41 , min_splits = 62
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 2, and leaf_no = 41 , min_splits = 82
# training metrics:
# R2: 0.6217396608043659
# RMSE: 47922.71793757798
# test metrics:
# R2: 0.6613143997312394
# RMSE: 48709.3143193345
#
#  when depth = 3, and leaf_no = 1 , min_splits = 2
# training metrics:
# R2: 0.7324146385696486
# RMSE: 40306.69720639019
# test metrics:
# R2: 0.7663979052098762
# RMSE: 40453.119401088
#
#  when depth = 3, and leaf_no = 1 , min_splits = 22
# training metrics:
# R2: 0.7324146385696486
# RMSE: 40306.69720639019
# test metrics:
# R2: 0.7663979052098762
# RMSE: 40453.119401088
#
#  when depth = 3, and leaf_no = 1 , min_splits = 42
# training metrics:
# R2: 0.7324146385696486
# RMSE: 40306.69720639019
# test metrics:
# R2: 0.7663979052098762
# RMSE: 40453.119401088
#
#  when depth = 3, and leaf_no = 1 , min_splits = 62
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 1 , min_splits = 82
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 11 , min_splits = 2
# training metrics:
# R2: 0.7174917320198839
# RMSE: 41415.37695100976
# test metrics:
# R2: 0.7487671313643132
# RMSE: 41951.92354229723
#
#  when depth = 3, and leaf_no = 11 , min_splits = 22
# training metrics:
# R2: 0.7174917320198839
# RMSE: 41415.37695100976
# test metrics:
# R2: 0.7487671313643132
# RMSE: 41951.92354229723
#
#  when depth = 3, and leaf_no = 11 , min_splits = 42
# training metrics:
# R2: 0.7174917320198839
# RMSE: 41415.37695100976
# test metrics:
# R2: 0.7487671313643132
# RMSE: 41951.92354229723
#
#  when depth = 3, and leaf_no = 11 , min_splits = 62
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 11 , min_splits = 82
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 21 , min_splits = 2
# training metrics:
# R2: 0.7152442741896616
# RMSE: 41579.78793709582
# test metrics:
# R2: 0.7452667030300653
# RMSE: 42243.17070481007
#
#  when depth = 3, and leaf_no = 21 , min_splits = 22
# training metrics:
# R2: 0.7152442741896616
# RMSE: 41579.78793709582
# test metrics:
# R2: 0.7452667030300653
# RMSE: 42243.17070481007
#
#  when depth = 3, and leaf_no = 21 , min_splits = 42
# training metrics:
# R2: 0.7152442741896616
# RMSE: 41579.78793709582
# test metrics:
# R2: 0.7452667030300653
# RMSE: 42243.17070481007
#
#  when depth = 3, and leaf_no = 21 , min_splits = 62
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 21 , min_splits = 82
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 31 , min_splits = 2
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 31 , min_splits = 22
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 31 , min_splits = 42
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 31 , min_splits = 62
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 31 , min_splits = 82
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 41 , min_splits = 2
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 41 , min_splits = 22
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 41 , min_splits = 42
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 41 , min_splits = 62
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 3, and leaf_no = 41 , min_splits = 82
# training metrics:
# R2: 0.702987971982163
# RMSE: 42465.18846362588
# test metrics:
# R2: 0.7163621732404764
# RMSE: 44575.44879621901
#
#  when depth = 4, and leaf_no = 1 , min_splits = 2
# training metrics:
# R2: 0.8066757748641139
# RMSE: 34260.14339340371
# test metrics:
# R2: 0.7852581871211819
# RMSE: 38785.7288918971
#
#  when depth = 4, and leaf_no = 1 , min_splits = 22
# training metrics:
# R2: 0.8055927802352788
# RMSE: 34355.97135582601
# test metrics:
# R2: 0.7833809416159153
# RMSE: 38954.889944745686
#
#  when depth = 4, and leaf_no = 1 , min_splits = 42
# training metrics:
# R2: 0.8055927802352788
# RMSE: 34355.97135582601
# test metrics:
# R2: 0.7833809416159153
# RMSE: 38954.889944745686
#
#  when depth = 4, and leaf_no = 1 , min_splits = 62
# training metrics:
# R2: 0.7478592901038797
# RMSE: 39126.186695557735
# test metrics:
# R2: 0.7346413198074121
# RMSE: 43115.18948665251
#
#  when depth = 4, and leaf_no = 1 , min_splits = 82
# training metrics:
# R2: 0.7478592901038797
# RMSE: 39126.186695557735
# test metrics:
# R2: 0.7346413198074121
# RMSE: 43115.18948665251
#
#  when depth = 4, and leaf_no = 11 , min_splits = 2
# training metrics:
# R2: 0.7806380318914268
# RMSE: 36494.44003024346
# test metrics:
# R2: 0.7643440480281403
# RMSE: 40630.564524580615
#
#  when depth = 4, and leaf_no = 11 , min_splits = 22
# training metrics:
# R2: 0.7806380318914268
# RMSE: 36494.44003024346
# test metrics:
# R2: 0.7643440480281403
# RMSE: 40630.564524580615
#
#  when depth = 4, and leaf_no = 11 , min_splits = 42
# training metrics:
# R2: 0.7776001485030485
# RMSE: 36746.27185752137
# test metrics:
# R2: 0.7624652740376116
# RMSE: 40792.20717280765
#
#  when depth = 4, and leaf_no = 11 , min_splits = 62
# training metrics:
# R2: 0.7478592901038797
# RMSE: 39126.186695557735
# test metrics:
# R2: 0.7346413198074121
# RMSE: 43115.18948665251
#
#  when depth = 4, and leaf_no = 11 , min_splits = 82
# training metrics:
# R2: 0.7478592901038797
# RMSE: 39126.186695557735
# test metrics:
# R2: 0.7346413198074121
# RMSE: 43115.18948665251
#
#  when depth = 4, and leaf_no = 21 , min_splits = 2
# training metrics:
# R2: 0.7727951881234387
# RMSE: 37141.10322441406
# test metrics:
# R2: 0.7630031389037764
# RMSE: 40745.996814575294
#
#  when depth = 4, and leaf_no = 21 , min_splits = 22
# training metrics:
# R2: 0.7727951881234387
# RMSE: 37141.10322441406
# test metrics:
# R2: 0.7630031389037764
# RMSE: 40745.996814575294
#
#  when depth = 4, and leaf_no = 21 , min_splits = 42
# training metrics:
# R2: 0.7727951881234387
# RMSE: 37141.10322441406
# test metrics:
# R2: 0.7630031389037764
# RMSE: 40745.996814575294
#
#  when depth = 4, and leaf_no = 21 , min_splits = 62
# training metrics:
# R2: 0.7478592901038797
# RMSE: 39126.186695557735
# test metrics:
# R2: 0.7346413198074121
# RMSE: 43115.18948665251
#
#  when depth = 4, and leaf_no = 21 , min_splits = 82
# training metrics:
# R2: 0.7478592901038797
# RMSE: 39126.186695557735
# test metrics:
# R2: 0.7346413198074121
# RMSE: 43115.18948665251
#
#  when depth = 4, and leaf_no = 31 , min_splits = 2
# training metrics:
# R2: 0.747141360170932
# RMSE: 39181.8498482547
# test metrics:
# R2: 0.7299896623230075
# RMSE: 43491.44585724683
#
#  when depth = 4, and leaf_no = 31 , min_splits = 22
# training metrics:
# R2: 0.747141360170932
# RMSE: 39181.8498482547
# test metrics:
# R2: 0.7299896623230075
# RMSE: 43491.44585724683
#
#  when depth = 4, and leaf_no = 31 , min_splits = 42
# training metrics:
# R2: 0.747141360170932
# RMSE: 39181.8498482547
# test metrics:
# R2: 0.7299896623230075
# RMSE: 43491.44585724683
#
#  when depth = 4, and leaf_no = 31 , min_splits = 62
# training metrics:
# R2: 0.747141360170932
# RMSE: 39181.8498482547
# test metrics:
# R2: 0.7299896623230075
# RMSE: 43491.44585724683
#
#  when depth = 4, and leaf_no = 31 , min_splits = 82
# training metrics:
# R2: 0.747141360170932
# RMSE: 39181.8498482547
# test metrics:
# R2: 0.7299896623230075
# RMSE: 43491.44585724683
#
#  when depth = 4, and leaf_no = 41 , min_splits = 2
# training metrics:
# R2: 0.7437240095115477
# RMSE: 39445.72999136656
# test metrics:
# R2: 0.7403844840800398
# RMSE: 42646.06574822395
#
#  when depth = 4, and leaf_no = 41 , min_splits = 22
# training metrics:
# R2: 0.7437240095115477
# RMSE: 39445.72999136656
# test metrics:
# R2: 0.7403844840800398
# RMSE: 42646.06574822395
#
#  when depth = 4, and leaf_no = 41 , min_splits = 42
# training metrics:
# R2: 0.7437240095115477
# RMSE: 39445.72999136656
# test metrics:
# R2: 0.7403844840800398
# RMSE: 42646.06574822395
#
#  when depth = 4, and leaf_no = 41 , min_splits = 62
# training metrics:
# R2: 0.7437240095115477
# RMSE: 39445.72999136656
# test metrics:
# R2: 0.7403844840800398
# RMSE: 42646.06574822395
#
#  when depth = 4, and leaf_no = 41 , min_splits = 82
# training metrics:
# R2: 0.7437240095115477
# RMSE: 39445.72999136656
# test metrics:
# R2: 0.7403844840800398
# RMSE: 42646.06574822395
#
#  when depth = 5, and leaf_no = 1 , min_splits = 2
# training metrics:
# R2: 0.8655439260320896
# RMSE: 28571.711106929328
# test metrics:
# R2: 0.7859794843101473
# RMSE: 38720.5353262123
#
#  when depth = 5, and leaf_no = 1 , min_splits = 22
# training metrics:
# R2: 0.8568373912401781
# RMSE: 29482.26456439452
# test metrics:
# R2: 0.8071307803439025
# RMSE: 36757.42768984903
#
#  when depth = 5, and leaf_no = 1 , min_splits = 42
# training metrics:
# R2: 0.8311416199031915
# RMSE: 32018.969215248224
# test metrics:
# R2: 0.8003010266401328
# RMSE: 37402.580470079156
#
#  when depth = 5, and leaf_no = 1 , min_splits = 62
# training metrics:
# R2: 0.7699632997427486
# RMSE: 37371.85041774151
# test metrics:
# R2: 0.7462950260735436
# RMSE: 42157.819564945676
#
#  when depth = 5, and leaf_no = 1 , min_splits = 82
# training metrics:
# R2: 0.7699632997427486
# RMSE: 37371.85041774151
# test metrics:
# R2: 0.7462950260735436
# RMSE: 42157.819564945676
#
#  when depth = 5, and leaf_no = 11 , min_splits = 2
# training metrics:
# R2: 0.8141930078387958
# RMSE: 33587.45238621923
# test metrics:
# R2: 0.7866808313798443
# RMSE: 38657.039500875835
#
#  when depth = 5, and leaf_no = 11 , min_splits = 22
# training metrics:
# R2: 0.8141930078387958
# RMSE: 33587.45238621923
# test metrics:
# R2: 0.7826185464218036
# RMSE: 39023.380998601584
#
#  when depth = 5, and leaf_no = 11 , min_splits = 42
# training metrics:
# R2: 0.8028349278510708
# RMSE: 34598.79936112623
# test metrics:
# R2: 0.780877832741735
# RMSE: 39179.31216678688
#
#  when depth = 5, and leaf_no = 11 , min_splits = 62
# training metrics:
# R2: 0.7696492394228582
# RMSE: 37397.35289624082
# test metrics:
# R2: 0.7477874997534495
# RMSE: 42033.6354731576
#
#  when depth = 5, and leaf_no = 11 , min_splits = 82
# training metrics:
# R2: 0.7696492394228582
# RMSE: 37397.35289624082
# test metrics:
# R2: 0.7477874997534495
# RMSE: 42033.6354731576
#
#  when depth = 5, and leaf_no = 21 , min_splits = 2
# training metrics:
# R2: 0.798029967471461
# RMSE: 35017.85216901777
# test metrics:
# R2: 0.7814156976078999
# RMSE: 39131.19717369576
#
#  when depth = 5, and leaf_no = 21 , min_splits = 22
# training metrics:
# R2: 0.798029967471461
# RMSE: 35017.85216901777
# test metrics:
# R2: 0.7814156976078999
# RMSE: 39131.19717369576
#
#  when depth = 5, and leaf_no = 21 , min_splits = 42
# training metrics:
# R2: 0.798029967471461
# RMSE: 35017.85216901777
# test metrics:
# R2: 0.7814156976078999
# RMSE: 39131.19717369576
#
#  when depth = 5, and leaf_no = 21 , min_splits = 62
# training metrics:
# R2: 0.7696492394228582
# RMSE: 37397.35289624082
# test metrics:
# R2: 0.7477874997534495
# RMSE: 42033.6354731576
#
#  when depth = 5, and leaf_no = 21 , min_splits = 82
# training metrics:
# R2: 0.7696492394228582
# RMSE: 37397.35289624082
# test metrics:
# R2: 0.7477874997534495
# RMSE: 42033.6354731576
#
#  when depth = 5, and leaf_no = 31 , min_splits = 2
# training metrics:
# R2: 0.7685180154182925
# RMSE: 37489.06731462067
# test metrics:
# R2: 0.7481464030842705
# RMSE: 42003.71748236076
#
#  when depth = 5, and leaf_no = 31 , min_splits = 22
# training metrics:
# R2: 0.7685180154182925
# RMSE: 37489.06731462067
# test metrics:
# R2: 0.7481464030842705
# RMSE: 42003.71748236076
#
#  when depth = 5, and leaf_no = 31 , min_splits = 42
# training metrics:
# R2: 0.7685180154182925
# RMSE: 37489.06731462067
# test metrics:
# R2: 0.7481464030842705
# RMSE: 42003.71748236076
#
#  when depth = 5, and leaf_no = 31 , min_splits = 62
# training metrics:
# R2: 0.7685180154182925
# RMSE: 37489.06731462067
# test metrics:
# R2: 0.7481464030842705
# RMSE: 42003.71748236076
#
#  when depth = 5, and leaf_no = 31 , min_splits = 82
# training metrics:
# R2: 0.7685180154182925
# RMSE: 37489.06731462067
# test metrics:
# R2: 0.7481464030842705
# RMSE: 42003.71748236076
#
#  when depth = 5, and leaf_no = 41 , min_splits = 2
# training metrics:
# R2: 0.765100664758908
# RMSE: 37764.77757303462
# test metrics:
# R2: 0.7585412248413027
# RMSE: 41127.76851940775
#
#  when depth = 5, and leaf_no = 41 , min_splits = 22
# training metrics:
# R2: 0.765100664758908
# RMSE: 37764.77757303462
# test metrics:
# R2: 0.7585412248413027
# RMSE: 41127.76851940775
#
#  when depth = 5, and leaf_no = 41 , min_splits = 42
# training metrics:
# R2: 0.765100664758908
# RMSE: 37764.77757303462
# test metrics:
# R2: 0.7585412248413027
# RMSE: 41127.76851940775
#
#  when depth = 5, and leaf_no = 41 , min_splits = 62
# training metrics:
# R2: 0.765100664758908
# RMSE: 37764.77757303462
# test metrics:
# R2: 0.7585412248413027
# RMSE: 41127.76851940775
#
#  when depth = 5, and leaf_no = 41 , min_splits = 82
# training metrics:
# R2: 0.765100664758908
# RMSE: 37764.77757303462
# test metrics:
# R2: 0.7585412248413027
# RMSE: 41127.76851940775
#
#  when depth = 6, and leaf_no = 1 , min_splits = 2
# training metrics:
# R2: 0.9131571617363949
# RMSE: 22962.176018547816
# test metrics:
# R2: 0.8057850478635228
# RMSE: 36885.44106149894
#
#  when depth = 6, and leaf_no = 1 , min_splits = 22
# training metrics:
# R2: 0.8897258717263559
# RMSE: 25875.14867866281
# test metrics:
# R2: 0.8164799738620432
# RMSE: 35855.466813162224
#
#  when depth = 6, and leaf_no = 1 , min_splits = 42
# training metrics:
# R2: 0.851066220111214
# RMSE: 30070.638049333254
# test metrics:
# R2: 0.820073560822339
# RMSE: 35502.68036538156
#
#  when depth = 6, and leaf_no = 1 , min_splits = 62
# training metrics:
# R2: 0.7813490696818126
# RMSE: 36435.24565844034
# test metrics:
# R2: 0.7576684083858675
# RMSE: 41202.03505170926
#
#  when depth = 6, and leaf_no = 1 , min_splits = 82
# training metrics:
# R2: 0.779883279177814
# RMSE: 36557.168829231574
# test metrics:
# R2: 0.7571137460999489
# RMSE: 41249.16087794774
#
#  when depth = 6, and leaf_no = 11 , min_splits = 2
# training metrics:
# R2: 0.8364195326487158
# RMSE: 31514.597125272627
# test metrics:
# R2: 0.803627524658396
# RMSE: 37089.75436883909
#
#  when depth = 6, and leaf_no = 11 , min_splits = 22
# training metrics:
# R2: 0.8364195326487158
# RMSE: 31514.597125272627
# test metrics:
# R2: 0.7995652397003553
# RMSE: 37471.421653448946
#
#  when depth = 6, and leaf_no = 11 , min_splits = 42
# training metrics:
# R2: 0.8228189211188685
# RMSE: 32798.55482509708
# test metrics:
# R2: 0.7960432257323785
# RMSE: 37799.20947669272
#
#  when depth = 6, and leaf_no = 11 , min_splits = 62
# training metrics:
# R2: 0.781234598047357
# RMSE: 36444.781991919066
# test metrics:
# R2: 0.75587379242635
# RMSE: 41354.31696726423
#
#  when depth = 6, and leaf_no = 11 , min_splits = 82
# training metrics:
# R2: 0.7781246030108399
# RMSE: 36702.9194841404
# test metrics:
# R2: 0.7553907448605798
# RMSE: 41395.210221886286
#
#  when depth = 6, and leaf_no = 21 , min_splits = 2
# training metrics:
# R2: 0.8156206545240056
# RMSE: 33458.1690963709
# test metrics:
# R2: 0.7950828019366137
# RMSE: 37888.10238813036
#
#  when depth = 6, and leaf_no = 21 , min_splits = 22
# training metrics:
# R2: 0.8156206545240056
# RMSE: 33458.1690963709
# test metrics:
# R2: 0.7950828019366137
# RMSE: 37888.10238813036
#
#  when depth = 6, and leaf_no = 21 , min_splits = 42
# training metrics:
# R2: 0.8156206545240056
# RMSE: 33458.1690963709
# test metrics:
# R2: 0.7950828019366137
# RMSE: 37888.10238813036
#
#  when depth = 6, and leaf_no = 21 , min_splits = 62
# training metrics:
# R2: 0.781234598047357
# RMSE: 36444.781991919066
# test metrics:
# R2: 0.75587379242635
# RMSE: 41354.31696726423
#
#  when depth = 6, and leaf_no = 21 , min_splits = 82
# training metrics:
# R2: 0.7781246030108399
# RMSE: 36702.9194841404
# test metrics:
# R2: 0.7553907448605798
# RMSE: 41395.210221886286
#
#  when depth = 6, and leaf_no = 31 , min_splits = 2
# training metrics:
# R2: 0.7810491086743102
# RMSE: 36460.2293326479
# test metrics:
# R2: 0.7548305418709463
# RMSE: 41442.58467311837
#
#  when depth = 6, and leaf_no = 31 , min_splits = 22
# training metrics:
# R2: 0.7810491086743102
# RMSE: 36460.2293326479
# test metrics:
# R2: 0.7548305418709463
# RMSE: 41442.58467311837
#
#  when depth = 6, and leaf_no = 31 , min_splits = 42
# training metrics:
# R2: 0.7810491086743102
# RMSE: 36460.2293326479
# test metrics:
# R2: 0.7548305418709463
# RMSE: 41442.58467311837
#
#  when depth = 6, and leaf_no = 31 , min_splits = 62
# training metrics:
# R2: 0.7810491086743102
# RMSE: 36460.2293326479
# test metrics:
# R2: 0.7548305418709463
# RMSE: 41442.58467311837
#
#  when depth = 6, and leaf_no = 31 , min_splits = 82
# training metrics:
# R2: 0.7745276916924755
# RMSE: 36999.22632121557
# test metrics:
# R2: 0.7500629623422024
# RMSE: 41843.59201143042
#
#  when depth = 6, and leaf_no = 41 , min_splits = 2
# training metrics:
# R2: 0.7711103410330911
# RMSE: 37278.55959380874
# test metrics:
# R2: 0.7604577840992346
# RMSE: 40964.219185370195
#
#  when depth = 6, and leaf_no = 41 , min_splits = 22
# training metrics:
# R2: 0.7711103410330911
# RMSE: 37278.55959380874
# test metrics:
# R2: 0.7604577840992346
# RMSE: 40964.219185370195
#
#  when depth = 6, and leaf_no = 41 , min_splits = 42
# training metrics:
# R2: 0.7711103410330911
# RMSE: 37278.55959380874
# test metrics:
# R2: 0.7604577840992346
# RMSE: 40964.219185370195
#
#  when depth = 6, and leaf_no = 41 , min_splits = 62
# training metrics:
# R2: 0.7711103410330911
# RMSE: 37278.55959380874
# test metrics:
# R2: 0.7604577840992346
# RMSE: 40964.219185370195
#
#  when depth = 6, and leaf_no = 41 , min_splits = 82
# training metrics:
# R2: 0.7711103410330911
# RMSE: 37278.55959380874
# test metrics:
# R2: 0.7604577840992346
# RMSE: 40964.219185370195
#
#  when depth = 7, and leaf_no = 1 , min_splits = 2
# training metrics:
# R2: 0.9455363545428107
# RMSE: 18184.41736784856
# test metrics:
# R2: 0.7855774432875374
# RMSE: 38756.88684045141
#
#  when depth = 7, and leaf_no = 1 , min_splits = 22
# training metrics:
# R2: 0.9074310220410817
# RMSE: 23707.118561252086
# test metrics:
# R2: 0.8246149301257766
# RMSE: 35051.77053495389
#
#  when depth = 7, and leaf_no = 1 , min_splits = 42
# training metrics:
# R2: 0.8621491762602125
# RMSE: 28930.152307757442
# test metrics:
# R2: 0.8231089869123045
# RMSE: 35201.93482268704
#
#  when depth = 7, and leaf_no = 1 , min_splits = 62
# training metrics:
# R2: 0.7856546092752279
# RMSE: 36074.73186028781
# test metrics:
# R2: 0.7602835665167124
# RMSE: 40979.11299033901
#
#  when depth = 7, and leaf_no = 1 , min_splits = 82
# training metrics:
# R2: 0.7831345519255353
# RMSE: 36286.17737812012
# test metrics:
# R2: 0.7578798788128126
# RMSE: 41184.05367015366
#
#  when depth = 7, and leaf_no = 11 , min_splits = 2
# training metrics:
# R2: 0.8510981107435147
# RMSE: 30067.418420439986
# test metrics:
# R2: 0.8085230056297167
# RMSE: 36624.520774706
#
#  when depth = 7, and leaf_no = 11 , min_splits = 22
# training metrics:
# R2: 0.8510981107435147
# RMSE: 30067.418420439986
# test metrics:
# R2: 0.8085230056297167
# RMSE: 36624.520774706
#
#  when depth = 7, and leaf_no = 11 , min_splits = 42
# training metrics:
# R2: 0.8314377915664788
# RMSE: 31990.876818307326
# test metrics:
# R2: 0.8052773919429743
# RMSE: 36933.616786296516
#
#  when depth = 7, and leaf_no = 11 , min_splits = 62
# training metrics:
# R2: 0.7848694297143535
# RMSE: 36140.74505891121
# test metrics:
# R2: 0.7613828334963556
# RMSE: 40885.04612387687
#
#  when depth = 7, and leaf_no = 11 , min_splits = 82
# training metrics:
# R2: 0.7808325018123761
# RMSE: 36478.25982234395
# test metrics:
# R2: 0.7594437347571001
# RMSE: 41050.83412676319
#
#  when depth = 7, and leaf_no = 21 , min_splits = 2
# training metrics:
# R2: 0.8224685712826991
# RMSE: 32830.96599891222
# test metrics:
# R2: 0.7997686965201656
# RMSE: 37452.39862584219
#
#  when depth = 7, and leaf_no = 21 , min_splits = 22
# training metrics:
# R2: 0.8224685712826991
# RMSE: 32830.96599891222
# test metrics:
# R2: 0.7997686965201656
# RMSE: 37452.39862584219
#
#  when depth = 7, and leaf_no = 21 , min_splits = 42
# training metrics:
# R2: 0.8224685712826991
# RMSE: 32830.96599891222
# test metrics:
# R2: 0.7997686965201656
# RMSE: 37452.39862584219
#
#  when depth = 7, and leaf_no = 21 , min_splits = 62
# training metrics:
# R2: 0.7847485067789233
# RMSE: 36150.900823917465
# test metrics:
# R2: 0.761349156532995
# RMSE: 40887.931154410646
#
#  when depth = 7, and leaf_no = 21 , min_splits = 82
# training metrics:
# R2: 0.7808325018123761
# RMSE: 36478.25982234395
# test metrics:
# R2: 0.7594437347571001
# RMSE: 41050.83412676319
#
#  when depth = 7, and leaf_no = 31 , min_splits = 2
# training metrics:
# R2: 0.782868504527484
# RMSE: 36308.428234995445
# test metrics:
# R2: 0.7570818042243321
# RMSE: 41251.87311923207
#
#  when depth = 7, and leaf_no = 31 , min_splits = 22
# training metrics:
# R2: 0.782868504527484
# RMSE: 36308.428234995445
# test metrics:
# R2: 0.7570818042243321
# RMSE: 41251.87311923207
#
#  when depth = 7, and leaf_no = 31 , min_splits = 42
# training metrics:
# R2: 0.782868504527484
# RMSE: 36308.428234995445
# test metrics:
# R2: 0.7570818042243321
# RMSE: 41251.87311923207
#
#  when depth = 7, and leaf_no = 31 , min_splits = 62
# training metrics:
# R2: 0.782868504527484
# RMSE: 36308.428234995445
# test metrics:
# R2: 0.7570818042243321
# RMSE: 41251.87311923207
#
#  when depth = 7, and leaf_no = 31 , min_splits = 82
# training metrics:
# R2: 0.7755902484612537
# RMSE: 36911.94242042405
# test metrics:
# R2: 0.7510510821025449
# RMSE: 41760.79630607061
#
#  when depth = 7, and leaf_no = 41 , min_splits = 2
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 7, and leaf_no = 41 , min_splits = 22
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 7, and leaf_no = 41 , min_splits = 42
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 7, and leaf_no = 41 , min_splits = 62
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 7, and leaf_no = 41 , min_splits = 82
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 8, and leaf_no = 1 , min_splits = 2
# training metrics:
# R2: 0.9689388383032856
# RMSE: 13732.666854461571
# test metrics:
# R2: 0.7821257229069231
# RMSE: 39067.59073185878
#
#  when depth = 8, and leaf_no = 1 , min_splits = 22
# training metrics:
# R2: 0.9165219410986902
# RMSE: 22512.93970657491
# test metrics:
# R2: 0.8220849114265756
# RMSE: 35303.68508429626
#
#  when depth = 8, and leaf_no = 1 , min_splits = 42
# training metrics:
# R2: 0.8664570611662791
# RMSE: 28474.525908498203
# test metrics:
# R2: 0.823210305285654
# RMSE: 35191.852022062056
#
#  when depth = 8, and leaf_no = 1 , min_splits = 62
# training metrics:
# R2: 0.7881319965559328
# RMSE: 35865.65150460132
# test metrics:
# R2: 0.7601614303056936
# RMSE: 40989.55114879449
#
#  when depth = 8, and leaf_no = 1 , min_splits = 82
# training metrics:
# R2: 0.7831345519255353
# RMSE: 36286.17737812012
# test metrics:
# R2: 0.7578798788128126
# RMSE: 41184.05367015366
#
#  when depth = 8, and leaf_no = 11 , min_splits = 2
# training metrics:
# R2: 0.8573907142238505
# RMSE: 29425.234981390757
# test metrics:
# R2: 0.8048363648821493
# RMSE: 36975.418588280074
#
#  when depth = 8, and leaf_no = 11 , min_splits = 22
# training metrics:
# R2: 0.8573907142238505
# RMSE: 29425.234981390757
# test metrics:
# R2: 0.8050308472604242
# RMSE: 36956.990821947045
#
#  when depth = 8, and leaf_no = 11 , min_splits = 42
# training metrics:
# R2: 0.8340037477833847
# RMSE: 31746.450781552525
# test metrics:
# R2: 0.8048055568136706
# RMSE: 36978.33689904842
#
#  when depth = 8, and leaf_no = 11 , min_splits = 62
# training metrics:
# R2: 0.785390897462324
# RMSE: 36096.91663555229
# test metrics:
# R2: 0.7617062374927734
# RMSE: 40857.330451314
#
#  when depth = 8, and leaf_no = 11 , min_splits = 82
# training metrics:
# R2: 0.7808325018123761
# RMSE: 36478.25982234395
# test metrics:
# R2: 0.7594437347571001
# RMSE: 41050.83412676319
#
#  when depth = 8, and leaf_no = 21 , min_splits = 2
# training metrics:
# R2: 0.823906931790878
# RMSE: 32697.69718983645
# test metrics:
# R2: 0.8008820600550337
# RMSE: 37348.12856328453
#
#  when depth = 8, and leaf_no = 21 , min_splits = 22
# training metrics:
# R2: 0.823906931790878
# RMSE: 32697.69718983645
# test metrics:
# R2: 0.8008820600550337
# RMSE: 37348.12856328453
#
#  when depth = 8, and leaf_no = 21 , min_splits = 42
# training metrics:
# R2: 0.823906931790878
# RMSE: 32697.69718983645
# test metrics:
# R2: 0.8008820600550337
# RMSE: 37348.12856328453
#
#  when depth = 8, and leaf_no = 21 , min_splits = 62
# training metrics:
# R2: 0.7851113300605086
# RMSE: 36120.420384243196
# test metrics:
# R2: 0.7623437214752253
# RMSE: 40802.64304300493
#
#  when depth = 8, and leaf_no = 21 , min_splits = 82
# training metrics:
# R2: 0.7808325018123761
# RMSE: 36478.25982234395
# test metrics:
# R2: 0.7594437347571001
# RMSE: 41050.83412676319
#
#  when depth = 8, and leaf_no = 31 , min_splits = 2
# training metrics:
# R2: 0.7830767497762219
# RMSE: 36291.0128171478
# test metrics:
# R2: 0.7576902093877929
# RMSE: 41200.181670062324
#
#  when depth = 8, and leaf_no = 31 , min_splits = 22
# training metrics:
# R2: 0.7830767497762219
# RMSE: 36291.0128171478
# test metrics:
# R2: 0.7576902093877929
# RMSE: 41200.181670062324
#
#  when depth = 8, and leaf_no = 31 , min_splits = 42
# training metrics:
# R2: 0.7830767497762219
# RMSE: 36291.0128171478
# test metrics:
# R2: 0.7576902093877929
# RMSE: 41200.181670062324
#
#  when depth = 8, and leaf_no = 31 , min_splits = 62
# training metrics:
# R2: 0.7830767497762219
# RMSE: 36291.0128171478
# test metrics:
# R2: 0.7576902093877929
# RMSE: 41200.181670062324
#
#  when depth = 8, and leaf_no = 31 , min_splits = 82
# training metrics:
# R2: 0.7755902484612537
# RMSE: 36911.94242042405
# test metrics:
# R2: 0.7510510821025449
# RMSE: 41760.79630607061
#
#  when depth = 8, and leaf_no = 41 , min_splits = 2
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 8, and leaf_no = 41 , min_splits = 22
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 8, and leaf_no = 41 , min_splits = 42
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 8, and leaf_no = 41 , min_splits = 62
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 8, and leaf_no = 41 , min_splits = 82
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 9, and leaf_no = 1 , min_splits = 2
# training metrics:
# R2: 0.9829248457315746
# RMSE: 10181.88893270828
# test metrics:
# R2: 0.7730817848728656
# RMSE: 39870.192206343774
#
#  when depth = 9, and leaf_no = 1 , min_splits = 22
# training metrics:
# R2: 0.9220498183435517
# RMSE: 21754.775357396164
# test metrics:
# R2: 0.8171790903690042
# RMSE: 35787.10624226167
#
#  when depth = 9, and leaf_no = 1 , min_splits = 42
# training metrics:
# R2: 0.8684973334563054
# RMSE: 28256.17144011675
# test metrics:
# R2: 0.8226794517915494
# RMSE: 35244.648409800175
#
#  when depth = 9, and leaf_no = 1 , min_splits = 62
# training metrics:
# R2: 0.7891301978410893
# RMSE: 35781.06249844108
# test metrics:
# R2: 0.7590636835149711
# RMSE: 41083.249127958035
#
#  when depth = 9, and leaf_no = 1 , min_splits = 82
# training metrics:
# R2: 0.7831345519255353
# RMSE: 36286.17737812012
# test metrics:
# R2: 0.7578798788128126
# RMSE: 41184.05367015366
#
#  when depth = 9, and leaf_no = 11 , min_splits = 2
# training metrics:
# R2: 0.8584774923985994
# RMSE: 29312.90056703523
# test metrics:
# R2: 0.8088783941624691
# RMSE: 36590.516742337524
#
#  when depth = 9, and leaf_no = 11 , min_splits = 22
# training metrics:
# R2: 0.8584774923985994
# RMSE: 29312.90056703523
# test metrics:
# R2: 0.8086839117841942
# RMSE: 36609.12897948178
#
#  when depth = 9, and leaf_no = 11 , min_splits = 42
# training metrics:
# R2: 0.8344649964442187
# RMSE: 31702.313658307354
# test metrics:
# R2: 0.8046543419854927
# RMSE: 36992.6574663704
#
#  when depth = 9, and leaf_no = 11 , min_splits = 62
# training metrics:
# R2: 0.785390897462324
# RMSE: 36096.91663555229
# test metrics:
# R2: 0.7617062374927734
# RMSE: 40857.330451314
#
#  when depth = 9, and leaf_no = 11 , min_splits = 82
# training metrics:
# R2: 0.7808325018123761
# RMSE: 36478.25982234395
# test metrics:
# R2: 0.7594437347571001
# RMSE: 41050.83412676319
#
#  when depth = 9, and leaf_no = 21 , min_splits = 2
# training metrics:
# R2: 0.823906931790878
# RMSE: 32697.69718983645
# test metrics:
# R2: 0.8008820600550337
# RMSE: 37348.12856328453
#
#  when depth = 9, and leaf_no = 21 , min_splits = 22
# training metrics:
# R2: 0.823906931790878
# RMSE: 32697.69718983645
# test metrics:
# R2: 0.8008820600550337
# RMSE: 37348.12856328453
#
#  when depth = 9, and leaf_no = 21 , min_splits = 42
# training metrics:
# R2: 0.823906931790878
# RMSE: 32697.69718983645
# test metrics:
# R2: 0.8008820600550337
# RMSE: 37348.12856328453
#
#  when depth = 9, and leaf_no = 21 , min_splits = 62
# training metrics:
# R2: 0.7851113300605086
# RMSE: 36120.420384243196
# test metrics:
# R2: 0.7623437214752253
# RMSE: 40802.64304300493
#
#  when depth = 9, and leaf_no = 21 , min_splits = 82
# training metrics:
# R2: 0.7808325018123761
# RMSE: 36478.25982234395
# test metrics:
# R2: 0.7594437347571001
# RMSE: 41050.83412676319
#
#  when depth = 9, and leaf_no = 31 , min_splits = 2
# training metrics:
# R2: 0.7830767497762219
# RMSE: 36291.0128171478
# test metrics:
# R2: 0.7576902093877929
# RMSE: 41200.181670062324
#
#  when depth = 9, and leaf_no = 31 , min_splits = 22
# training metrics:
# R2: 0.7830767497762219
# RMSE: 36291.0128171478
# test metrics:
# R2: 0.7576902093877929
# RMSE: 41200.181670062324
#
#  when depth = 9, and leaf_no = 31 , min_splits = 42
# training metrics:
# R2: 0.7830767497762219
# RMSE: 36291.0128171478
# test metrics:
# R2: 0.7576902093877929
# RMSE: 41200.181670062324
#
#  when depth = 9, and leaf_no = 31 , min_splits = 62
# training metrics:
# R2: 0.7830767497762219
# RMSE: 36291.0128171478
# test metrics:
# R2: 0.7576902093877929
# RMSE: 41200.181670062324
#
#  when depth = 9, and leaf_no = 31 , min_splits = 82
# training metrics:
# R2: 0.7755902484612537
# RMSE: 36911.94242042405
# test metrics:
# R2: 0.7510510821025449
# RMSE: 41760.79630607061
#
#  when depth = 9, and leaf_no = 41 , min_splits = 2
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 9, and leaf_no = 41 , min_splits = 22
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 9, and leaf_no = 41 , min_splits = 42
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 9, and leaf_no = 41 , min_splits = 62
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064
#
#  when depth = 9, and leaf_no = 41 , min_splits = 82
# training metrics:
# R2: 0.7721728978018693
# RMSE: 37191.93125221275
# test metrics:
# R2: 0.7614459038595771
# RMSE: 40879.64247844064

# %% [markdown]
# # Grid Search and CV

# %%
def run_gridsearch(X, y, clf, param_grid,  cv=5):
    """Run a grid search for best Decision Tree parameters.

    Args
    ----
    X -- features
    y -- targets (classes)
    cf -- scikit-learn Decision Tree
    param_grid -- [dict] parameter settings to test
    cv -- fold of cross-validation, default 5

    Returns
    -------
    top_params -- [dict] from report()
    """
    grid_search = GridSearchCV(clf,
                               param_grid=param_grid,
                               cv=cv)
    start = time()
    grid_search.fit(X, y)

    print(("\nGridSearchCV took {:.2f} "
           "seconds for {:d} candidate "
           "parameter settings.").format(time() - start,
                len(grid_search.grid_scores_)))

    top_params = report(grid_search.grid_scores_, 30)
    return  top_params


def report(grid_scores, n_top=30):
    """Report top n_top parameters settings, default n_top=3.

    Args
    ----
    grid_scores -- output from grid or random search
    n_top -- how many to report, of top models

    Returns
    -------
    top_params -- [dict] top parameter settings found in
                  search
    """
    top_scores = sorted(grid_scores,
                        key=itemgetter(1),
                        reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Model with rank: {0}".format(i + 1))
        print(("Mean validation score: "
               "{0:.3f} (std: {1:.3f})").format(
               score.mean_validation_score,
               np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")

    return top_scores[0].parameters

# %%
print("-- Grid Parameter Search via 10-fold CV")

# set of parameters to test
param_grid = {"criterion": [ "mse","friedman_mse"],
              "min_samples_split": [10, 20,30],
              "max_depth": [2,4, 6,7,8,9],
              "min_samples_leaf": [5, 6,7,8,9,10,15,20],
              }

dt = tree.DecisionTreeRegressor()

ts_gs = run_gridsearch(x, Y, dt, param_grid, cv=10)
# Out:
# -- Grid Parameter Search via 10-fold CV
#
# GridSearchCV took 21.70 seconds for 160 candidate parameter settings.
# Model with rank: 1
# Mean validation score: 0.777 (std: 0.051)
# Parameters: {'criterion': 'mse', 'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 2
# Mean validation score: 0.777 (std: 0.051)
# Parameters: {'criterion': 'mse', 'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 40}
#
# Model with rank: 3
# Mean validation score: 0.777 (std: 0.051)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 4
# Mean validation score: 0.777 (std: 0.051)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 40}
#
# Model with rank: 5
# Mean validation score: 0.777 (std: 0.051)
# Parameters: {'criterion': 'mse', 'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 6
# Mean validation score: 0.777 (std: 0.051)
# Parameters: {'criterion': 'mse', 'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 7
# Mean validation score: 0.777 (std: 0.051)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 8
# Mean validation score: 0.777 (std: 0.051)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 6, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 9
# Mean validation score: 0.775 (std: 0.053)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 6, 'min_samples_leaf': 15, 'min_samples_split': 20}
#
# Model with rank: 10
# Mean validation score: 0.775 (std: 0.053)
# Parameters: {'criterion': 'mse', 'max_depth': 6, 'min_samples_leaf': 15, 'min_samples_split': 10}
#
# Model with rank: 11
# Mean validation score: 0.775 (std: 0.053)
# Parameters: {'criterion': 'mse', 'max_depth': 6, 'min_samples_leaf': 15, 'min_samples_split': 20}
#
# Model with rank: 12
# Mean validation score: 0.775 (std: 0.053)
# Parameters: {'criterion': 'mse', 'max_depth': 6, 'min_samples_leaf': 15, 'min_samples_split': 30}
#
# Model with rank: 13
# Mean validation score: 0.775 (std: 0.053)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 6, 'min_samples_leaf': 15, 'min_samples_split': 30}
#
# Model with rank: 14
# Mean validation score: 0.774 (std: 0.053)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 6, 'min_samples_leaf': 15, 'min_samples_split': 10}
#
# Model with rank: 15
# Mean validation score: 0.769 (std: 0.045)
# Parameters: {'criterion': 'mse', 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 16
# Mean validation score: 0.769 (std: 0.045)
# Parameters: {'criterion': 'mse', 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 17
# Mean validation score: 0.769 (std: 0.045)
# Parameters: {'criterion': 'mse', 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 18
# Mean validation score: 0.769 (std: 0.045)
# Parameters: {'criterion': 'mse', 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 40}
#
# Model with rank: 19
# Mean validation score: 0.769 (std: 0.045)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 20
# Mean validation score: 0.769 (std: 0.045)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 21
# Mean validation score: 0.769 (std: 0.045)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 22
# Mean validation score: 0.769 (std: 0.045)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 40}
#
# Model with rank: 23
# Mean validation score: 0.769 (std: 0.049)
# Parameters: {'criterion': 'mse', 'max_depth': 6, 'min_samples_leaf': 15, 'min_samples_split': 40}
#
# Model with rank: 24
# Mean validation score: 0.769 (std: 0.049)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 6, 'min_samples_leaf': 15, 'min_samples_split': 40}
#
# Model with rank: 25
# Mean validation score: 0.766 (std: 0.048)
# Parameters: {'criterion': 'mse', 'max_depth': 5, 'min_samples_leaf': 15, 'min_samples_split': 20}
#
# Model with rank: 26
# Mean validation score: 0.766 (std: 0.048)
# Parameters: {'criterion': 'mse', 'max_depth': 5, 'min_samples_leaf': 15, 'min_samples_split': 30}
#
# Model with rank: 27
# Mean validation score: 0.766 (std: 0.048)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 5, 'min_samples_leaf': 15, 'min_samples_split': 10}
#
# Model with rank: 28
# Mean validation score: 0.765 (std: 0.048)
# Parameters: {'criterion': 'mse', 'max_depth': 5, 'min_samples_leaf': 15, 'min_samples_split': 10}
#
# Model with rank: 29
# Mean validation score: 0.765 (std: 0.048)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 5, 'min_samples_leaf': 15, 'min_samples_split': 20}
#
# Model with rank: 30
# Mean validation score: 0.765 (std: 0.048)
# Parameters: {'criterion': 'friedman_mse', 'max_depth': 5, 'min_samples_leaf': 15, 'min_samples_split': 30}

# %%
print("\n-- Best Parameters:")
for k, v in ts_gs.items():
    print("parameter: {:<20s} setting: {}".format(k, v))
# Out:
# -- Best Parameters:
# parameter: criterion            setting: mse
# parameter: max_depth            setting: 6
# parameter: min_samples_leaf     setting: 20
# parameter: min_samples_split    setting: 10

# %%
# test the retuned best parameters
print("\n\n-- Testing best parameters [Grid]...")
dt_ts_gs = tree.DecisionTreeRegressor(**ts_gs)
scores = cross_val_score(dt_ts_gs, x, Y, cv=10)
print("mean: {:.3f} (std: {:.3f})".format(scores.mean(),
                                          scores.std()),
                                          end="\n\n" )
# Out:
# -- Testing best parameters [Grid]...
# mean: 0.777 (std: 0.051)

# %%
dt_ts_gs.fit(x_train,Y_train)
g = plot_tree(dt_ts_gs, list(x_train.columns))
g

# %%
print("training metrics: ")
y_train_pred = dt_ts_gs.predict(x_train)
get_score(Y_train, y_train_pred)
print("test metrics: ")
y_test_pred = dt_ts_gs.predict(x_vali)
get_score(Y_vali, y_test_pred)
# Out:
# training metrics:
# R2: 0.8189565045813134
# RMSE: 33154.119633830596
# test metrics:
# R2: 0.7955636461209593
# RMSE: 37843.62351118202

# %% [markdown]
# # Final Submission

# %%
y_pred = dt_ts_gs.predict(x_test)
test['SalePrice'] = y_pred
result = test[['Id','SalePrice']]
result.to_csv('submission_dt_ts_gs.csv',index=False)
# Out:
# /Users/jitxu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
